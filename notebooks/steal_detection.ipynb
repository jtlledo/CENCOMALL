# %% [markdown]
# ### Nota: El modelo solo funciona con tensorflow y keras 2.15, para hacer su instalación se debe tener Python 3.9

# %%
import os
from tensorflow.keras.models import load_model
from collections import defaultdict
import cv2
import numpy as np
import time
import json
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors
from collections import deque
# Out:
# WARNING:tensorflow:From c:\Users\joaqu\miniconda3\envs\yoloenv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
class Person:
    def __init__(self, id, x1, y1, x2, y2):
        self.id = id
        self.x1 = x1
        self.y1 = y1
        self.x2 = x2
        self.y2 = y2
        self.thief = False  # Indica si la persona es sospechosa de robo
        self.zones = list()

    def set_thief_status(self, status: bool):
        """Actualizar estado de sospecha de la persona."""
        self.thief = status

    def get_color(self):
        """Devuelve el color correspondiente a la persona según su estado."""
        return (0, 0, 255) if self.thief else (0, 255, 0)

    def draw(self, frame):
        """Dibuja un rectángulo alrededor de la persona."""
        cv2.rectangle(frame, (self.x1, self.y1), (self.x2, self.y2), self.get_color(), 2)
        label = "Ladrón" if self.thief else "Persona"
        cv2.putText(frame, label, (self.x1, self.y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, self.get_color(), 2)

# %%
class YoloDetector:
    def __init__(self, yolo_model, steal_model, confidence_threshold=0.7, video_path="video.mp4", 
                 individual_persons=False, output_video_path="output_video.mp4"):
        
        self.confidence_threshold = confidence_threshold
        self.video_path = video_path
        self.output_video_path = output_video_path  # Ruta para guardar el video procesado
        self.people = list()
        self.zones = list()

        self.IMG_SIZE = (90, 90)
        self.SEQUENCE_LENGTH = 160  

        self.frame_queue = deque(maxlen=self.SEQUENCE_LENGTH)

        # Cargar modelo YOLO
        self.yolo_model = YOLO(yolo_model)
        # Cargar modelo LRCN para robos
        self.steal_model = load_model(steal_model)

        if individual_persons:
            self.detect_thief()
        else:
            self.detect_thief_seen()

    def preprocess_frame(self, frame):
        """Preprocesa un frame para que sea compatible con el modelo."""
        frame = cv2.resize(frame, self.IMG_SIZE)  # Redimensionar a 90x90
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convertir a escala de grises
        frame = frame / 255.0  # Normalización
        frame = np.expand_dims(frame, axis=-1)  # Añadir canal de profundidad
        return frame

    def predict_thief(self, frame):
        input_sequence = np.expand_dims(np.array(frame), axis=0)
        predictions = self.steal_model.predict(input_sequence)

        # Obtenemos el indice del mayor valor de la predicción
        prediction = np.argmax(predictions)
        confidence = predictions[0][prediction]

        return prediction, confidence

    def detect_thief(self):
        cap = cv2.VideoCapture(self.video_path)

        # Obtener las propiedades del video (como el FPS y la resolución)
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = cap.get(cv2.CAP_PROP_FPS)

        # Configurar VideoWriter para guardar el video de salida
        fourcc = cv2.VideoWriter_fourcc(*"XVID")  # Usar códec XVID
        out = cv2.VideoWriter(self.output_video_path, fourcc, fps, (width, height))

        while True:
            ret, frame = cap.read()

            if not ret or frame is None:
                print("Fin del video o error en la lectura del frame.")
                break

            annotator = Annotator(frame, line_width=2)
            results = self.yolo_model.track(frame, persist=True)

            if results[0].boxes.id is not None:
                boxes = results[0].boxes.xyxy.cpu().numpy()
                confs = results[0].boxes.conf.cpu().numpy()
                class_ids = results[0].boxes.cls.cpu().numpy()
                track_ids = results[0].boxes.id.int().cpu().tolist()
                
                current_frame_people = set()

                for box, conf, class_id, track_id in zip(boxes, confs, class_ids, track_ids):
                    if int(class_id) == 0:  # Detectar solo personas

                        centroid_x = int((box[0] + box[2]) / 2)
                        centroid_y = int((box[1] + box[3]) / 2)
                        cv2.circle(frame, (centroid_x, centroid_y), 5, (0, 0, 255), -1)

                        # Extraer coordenadas del bounding box
                        x1, y1, x2, y2 = map(int, box)  # Convertir a enteros

                        # Asegurar que las coordenadas estén dentro del tamaño del frame
                        x1, y1 = max(0, x1), max(0, y1)
                        x2, y2 = min(width, x2), min(height, y2)

                        # Recortar la región de la persona detectada
                        person_crop = frame[y1:y2, x1:x2]

                        processed_frame = self.preprocess_frame(person_crop)
                        self.frame_queue.append(processed_frame)
                        
                        if len(self.frame_queue) == self.SEQUENCE_LENGTH:
                            prediction, confidence = self.predict_thief(self.frame_queue)

                            if str(prediction) == "0" and confidence > self.confidence_threshold:
                                label = "Ladron"
                                annotator.box_label(box, label, color=(0, 0, 255))

            # Guardar el frame procesado en el video de salida
            out.write(frame)

            cv2.imshow("object-detection-tracking", frame)

            if cv2.waitKey(1) & 0xFF == ord("q"):
                break

        cap.release()
        out.release()  # Liberar el VideoWriter
        cv2.destroyAllWindows()

    def detect_thief_seen(self):
        cap = cv2.VideoCapture(self.video_path)

        # Obtener las propiedades del video (como el FPS y la resolución)
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = cap.get(cv2.CAP_PROP_FPS)

        # Configurar VideoWriter para guardar el video de salida
        fourcc = cv2.VideoWriter_fourcc(*"XVID")  # Usar códec XVID
        out = cv2.VideoWriter(self.output_video_path, fourcc, fps, (width, height))

        while True:
            ret, frame = cap.read()

            if ret == False:
                break

            processed_frame = self.preprocess_frame(frame)
            self.frame_queue.append(processed_frame)
            
            if len(self.frame_queue) == self.SEQUENCE_LENGTH:
                prediction, confidence = self.predict_thief(self.frame_queue)

                if str(prediction) == "0" and confidence > self.confidence_threshold:
                    label = "Robo detectado"
                    cv2.putText(frame, label, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

            # Guardar el frame procesado en el video de salida
            out.write(frame)

            cv2.imshow("object-detection-tracking", frame)

            if cv2.waitKey(1) & 0xFF == ord("q"):
                break

        cap.release()
        out.release()  # Liberar el VideoWriter
        cv2.destroyAllWindows()

# %%
yolo_model = "../src/models/yolo11n.pt"
steal_model = "../src/models/lrcn_160S_90_90Q.h5"
video_path = "../data/robo1.mp4"
output_video_path = "../outputs/steal_output.mp4"
individual_persons = True
confidence_threshold = 0.7

detector = YoloDetector(yolo_model, steal_model, confidence_threshold, video_path, individual_persons, output_video_path)
# Out:
# WARNING:tensorflow:From c:\Users\joaqu\miniconda3\envs\yoloenv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\joaqu\miniconda3\envs\yoloenv\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
#
# 0: 384x640 1 person, 120.0ms
# Speed: 4.9ms preprocess, 120.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.0ms
# Speed: 5.4ms preprocess, 106.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 94.3ms
# Speed: 3.9ms preprocess, 94.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 91.9ms
# Speed: 2.8ms preprocess, 91.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.2ms
# Speed: 3.8ms preprocess, 97.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 89.3ms
# Speed: 2.6ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 158.6ms
# Speed: 2.6ms preprocess, 158.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.7ms
# Speed: 3.9ms preprocess, 177.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 130.1ms
# Speed: 4.9ms preprocess, 130.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 12.0ms preprocess, 100.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 117.4ms
# Speed: 4.2ms preprocess, 117.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 106.1ms
# Speed: 3.0ms preprocess, 106.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 93.5ms
# Speed: 2.7ms preprocess, 93.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 88.8ms
# Speed: 2.9ms preprocess, 88.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 97.4ms
# Speed: 3.7ms preprocess, 97.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 93.6ms
# Speed: 3.9ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 78.2ms
# Speed: 2.6ms preprocess, 78.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.4ms
# Speed: 3.2ms preprocess, 77.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 78.0ms
# Speed: 3.4ms preprocess, 78.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 88.3ms
# Speed: 3.5ms preprocess, 88.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 97.2ms
# Speed: 3.6ms preprocess, 97.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 90.2ms
# Speed: 2.8ms preprocess, 90.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 74.6ms
# Speed: 3.2ms preprocess, 74.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 76.2ms
# Speed: 3.8ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 72.9ms
# Speed: 3.5ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 74.5ms
# Speed: 3.6ms preprocess, 74.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 1 chair, 75.5ms
# Speed: 2.7ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 78.8ms
# Speed: 2.9ms preprocess, 78.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 78.7ms
# Speed: 3.5ms preprocess, 78.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.7ms
# Speed: 2.6ms preprocess, 80.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 75.3ms
# Speed: 4.2ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 82.2ms
# Speed: 3.6ms preprocess, 82.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 80.2ms
# Speed: 3.4ms preprocess, 80.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 253.6ms
# Speed: 5.2ms preprocess, 253.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 96.9ms
# Speed: 3.2ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 98.6ms
# Speed: 3.6ms preprocess, 98.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 97.3ms
# Speed: 3.4ms preprocess, 97.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 87.1ms
# Speed: 3.0ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 86.4ms
# Speed: 2.7ms preprocess, 86.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 126.6ms
# Speed: 11.3ms preprocess, 126.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 116.3ms
# Speed: 3.0ms preprocess, 116.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 125.3ms
# Speed: 7.0ms preprocess, 125.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 89.3ms
# Speed: 3.4ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 89.0ms
# Speed: 3.9ms preprocess, 89.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 130.5ms
# Speed: 19.1ms preprocess, 130.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 90.9ms
# Speed: 2.6ms preprocess, 90.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 87.1ms
# Speed: 3.6ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 116.3ms
# Speed: 4.5ms preprocess, 116.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 94.3ms
# Speed: 3.0ms preprocess, 94.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 85.4ms
# Speed: 3.4ms preprocess, 85.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 83.3ms
# Speed: 3.6ms preprocess, 83.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 78.9ms
# Speed: 3.2ms preprocess, 78.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.7ms
# Speed: 3.8ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.9ms
# Speed: 2.8ms preprocess, 76.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.4ms
# Speed: 2.8ms preprocess, 71.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.5ms
# Speed: 2.7ms preprocess, 77.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.6ms
# Speed: 2.8ms preprocess, 75.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 78.9ms
# Speed: 2.7ms preprocess, 78.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.2ms
# Speed: 3.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.7ms
# Speed: 2.6ms preprocess, 73.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.3ms
# Speed: 2.7ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.3ms
# Speed: 3.3ms preprocess, 75.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.2ms
# Speed: 3.0ms preprocess, 71.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 78.1ms
# Speed: 2.6ms preprocess, 78.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.1ms
# Speed: 2.8ms preprocess, 72.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.0ms
# Speed: 2.6ms preprocess, 74.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.2ms
# Speed: 2.7ms preprocess, 71.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.6ms
# Speed: 2.8ms preprocess, 77.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.7ms
# Speed: 2.8ms preprocess, 70.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.9ms
# Speed: 2.8ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.9ms
# Speed: 4.2ms preprocess, 80.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.0ms
# Speed: 2.7ms preprocess, 76.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.4ms
# Speed: 2.9ms preprocess, 74.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.0ms
# Speed: 3.2ms preprocess, 71.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.2ms
# Speed: 3.1ms preprocess, 72.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.8ms
# Speed: 2.8ms preprocess, 74.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.2ms
# Speed: 2.8ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.1ms
# Speed: 3.1ms preprocess, 76.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.6ms
# Speed: 3.1ms preprocess, 70.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.2ms
# Speed: 2.4ms preprocess, 74.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.5ms
# Speed: 3.3ms preprocess, 74.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.7ms
# Speed: 3.8ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.6ms
# Speed: 2.8ms preprocess, 71.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.4ms
# Speed: 2.9ms preprocess, 73.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.6ms
# Speed: 2.9ms preprocess, 72.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.2ms
# Speed: 2.5ms preprocess, 74.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.1ms
# Speed: 2.8ms preprocess, 73.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 72.1ms
# Speed: 2.8ms preprocess, 72.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.6ms
# Speed: 2.8ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.2ms
# Speed: 3.3ms preprocess, 72.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.8ms
# Speed: 2.9ms preprocess, 70.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.4ms
# Speed: 3.5ms preprocess, 73.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.5ms
# Speed: 2.9ms preprocess, 72.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.5ms
# Speed: 2.6ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.9ms
# Speed: 3.0ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.3ms
# Speed: 3.4ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.8ms
# Speed: 2.8ms preprocess, 73.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.3ms
# Speed: 2.7ms preprocess, 76.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.4ms
# Speed: 3.1ms preprocess, 74.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.1ms
# Speed: 3.0ms preprocess, 76.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.7ms
# Speed: 3.0ms preprocess, 75.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.7ms
# Speed: 4.1ms preprocess, 80.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.9ms
# Speed: 2.9ms preprocess, 71.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.1ms
# Speed: 3.3ms preprocess, 75.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.7ms
# Speed: 2.6ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 74.1ms
# Speed: 4.0ms preprocess, 74.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 74.1ms
# Speed: 3.4ms preprocess, 74.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 75.9ms
# Speed: 3.6ms preprocess, 75.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 73.5ms
# Speed: 3.4ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 72.9ms
# Speed: 3.4ms preprocess, 72.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 72.7ms
# Speed: 3.4ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 suitcase, 74.9ms
# Speed: 2.6ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 74.3ms
# Speed: 2.9ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 85.6ms
# Speed: 3.2ms preprocess, 85.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 72.3ms
# Speed: 3.3ms preprocess, 72.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 77.3ms
# Speed: 3.0ms preprocess, 77.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 77.5ms
# Speed: 3.4ms preprocess, 77.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 75.1ms
# Speed: 3.0ms preprocess, 75.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 73.4ms
# Speed: 4.1ms preprocess, 73.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 74.9ms
# Speed: 2.8ms preprocess, 74.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 76.6ms
# Speed: 3.5ms preprocess, 76.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 74.2ms
# Speed: 2.9ms preprocess, 74.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 71.9ms
# Speed: 2.8ms preprocess, 71.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 71.7ms
# Speed: 3.5ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.1ms
# Speed: 3.8ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.2ms
# Speed: 2.7ms preprocess, 74.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.7ms
# Speed: 2.7ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.3ms
# Speed: 2.4ms preprocess, 73.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.5ms
# Speed: 3.2ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 71.9ms
# Speed: 3.0ms preprocess, 71.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 74.2ms
# Speed: 2.7ms preprocess, 74.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.9ms
# Speed: 2.6ms preprocess, 73.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.1ms
# Speed: 3.4ms preprocess, 72.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.1ms
# Speed: 3.4ms preprocess, 74.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.9ms
# Speed: 3.6ms preprocess, 76.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.3ms
# Speed: 3.0ms preprocess, 75.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 78.4ms
# Speed: 3.2ms preprocess, 78.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 75.9ms
# Speed: 3.6ms preprocess, 75.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.8ms
# Speed: 2.9ms preprocess, 77.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 76.1ms
# Speed: 3.1ms preprocess, 76.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 74.6ms
# Speed: 2.9ms preprocess, 74.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.7ms
# Speed: 2.7ms preprocess, 74.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.7ms
# Speed: 3.8ms preprocess, 73.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.3ms
# Speed: 4.1ms preprocess, 76.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.8ms
# Speed: 2.8ms preprocess, 76.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.4ms
# Speed: 3.0ms preprocess, 73.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.4ms
# Speed: 2.9ms preprocess, 74.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 72.1ms
# Speed: 2.9ms preprocess, 72.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.6ms
# Speed: 2.5ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.1ms
# Speed: 2.8ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bottle, 71.4ms
# Speed: 3.1ms preprocess, 71.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 71.8ms
# Speed: 2.6ms preprocess, 71.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 72.4ms
# Speed: 2.8ms preprocess, 72.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 74.2ms
# Speed: 2.9ms preprocess, 74.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 73.3ms
# Speed: 2.6ms preprocess, 73.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 74.3ms
# Speed: 3.1ms preprocess, 74.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 1s 863ms/step
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 1 bottle, 75.7ms
# Speed: 4.0ms preprocess, 75.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 1 bottle, 70.5ms
# Speed: 2.7ms preprocess, 70.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 1 bottle, 77.6ms
# Speed: 2.0ms preprocess, 77.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 1 bottle, 80.4ms
# Speed: 2.7ms preprocess, 80.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 66ms/step
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 1 bottle, 83.5ms
# Speed: 2.8ms preprocess, 83.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 bottle, 73.0ms
# Speed: 2.2ms preprocess, 73.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 72.6ms
# Speed: 3.9ms preprocess, 72.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 70.5ms
# Speed: 2.4ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 73.0ms
# Speed: 2.7ms preprocess, 73.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 80.6ms
# Speed: 2.2ms preprocess, 80.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 71.4ms
# Speed: 3.1ms preprocess, 71.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 69.8ms
# Speed: 2.7ms preprocess, 69.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 90.7ms
# Speed: 3.5ms preprocess, 90.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 70.2ms
# Speed: 3.6ms preprocess, 70.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 70.0ms
# Speed: 3.4ms preprocess, 70.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 72.7ms
# Speed: 2.7ms preprocess, 72.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 72.1ms
# Speed: 1.9ms preprocess, 72.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 1 person, 1 backpack, 1 handbag, 1 bottle, 88.6ms
# Speed: 3.4ms preprocess, 88.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 78.8ms
# Speed: 3.3ms preprocess, 78.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 71.5ms
# Speed: 2.3ms preprocess, 71.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 70.6ms
# Speed: 2.5ms preprocess, 70.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 72.4ms
# Speed: 2.7ms preprocess, 72.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 72.7ms
# Speed: 2.0ms preprocess, 72.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 71.8ms
# Speed: 2.1ms preprocess, 71.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 79.1ms
# Speed: 2.1ms preprocess, 79.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 71.8ms
# Speed: 2.3ms preprocess, 71.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 74.4ms
# Speed: 2.7ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 71.3ms
# Speed: 2.6ms preprocess, 71.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 71.8ms
# Speed: 2.7ms preprocess, 71.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 74.7ms
# Speed: 2.5ms preprocess, 74.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 73.9ms
# Speed: 2.3ms preprocess, 73.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 1 backpack, 1 bottle, 73.1ms
# Speed: 3.5ms preprocess, 73.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 77.2ms
# Speed: 3.4ms preprocess, 77.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 73.9ms
# Speed: 3.1ms preprocess, 73.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 72.2ms
# Speed: 3.6ms preprocess, 72.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 1 bottle, 72.5ms
# Speed: 2.2ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 76.2ms
# Speed: 3.3ms preprocess, 76.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 69.6ms
# Speed: 2.6ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.4ms
# Speed: 2.8ms preprocess, 70.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.6ms
# Speed: 2.4ms preprocess, 70.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 90.6ms
# Speed: 3.1ms preprocess, 90.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.7ms
# Speed: 2.3ms preprocess, 70.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.4ms
# Speed: 2.2ms preprocess, 72.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 51ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.3ms
# Speed: 1.9ms preprocess, 72.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 82.2ms
# Speed: 2.6ms preprocess, 82.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 76.2ms
# Speed: 2.2ms preprocess, 76.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.9ms
# Speed: 3.7ms preprocess, 71.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 1 handbag, 80.3ms
# Speed: 3.2ms preprocess, 80.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 76.1ms
# Speed: 2.6ms preprocess, 76.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 71.0ms
# Speed: 2.9ms preprocess, 71.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 85.6ms
# Speed: 2.7ms preprocess, 85.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.1ms
# Speed: 3.0ms preprocess, 70.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 75.0ms
# Speed: 3.8ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 backpack, 70.6ms
# Speed: 2.8ms preprocess, 70.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.0ms
# Speed: 2.6ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.2ms
# Speed: 2.4ms preprocess, 70.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.6ms
# Speed: 2.9ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.0ms
# Speed: 2.3ms preprocess, 72.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 79ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.1ms
# Speed: 3.0ms preprocess, 70.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.9ms
# Speed: 3.2ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 74.6ms
# Speed: 2.1ms preprocess, 74.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.5ms
# Speed: 2.5ms preprocess, 73.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 75.3ms
# Speed: 2.7ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.4ms
# Speed: 3.9ms preprocess, 72.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.0ms
# Speed: 3.2ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 74.4ms
# Speed: 3.7ms preprocess, 74.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 74.7ms
# Speed: 2.9ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 73.2ms
# Speed: 2.0ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 73.2ms
# Speed: 3.2ms preprocess, 73.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 76.2ms
# Speed: 2.6ms preprocess, 76.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 71.4ms
# Speed: 3.5ms preprocess, 71.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 72.0ms
# Speed: 4.0ms preprocess, 72.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 74.3ms
# Speed: 2.6ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 71.7ms
# Speed: 2.7ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 71.4ms
# Speed: 3.5ms preprocess, 71.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 73.7ms
# Speed: 2.0ms preprocess, 73.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 71.3ms
# Speed: 2.2ms preprocess, 71.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 69.1ms
# Speed: 2.1ms preprocess, 69.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 74.3ms
# Speed: 2.8ms preprocess, 74.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 71.3ms
# Speed: 2.6ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 70.9ms
# Speed: 2.6ms preprocess, 70.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 69.3ms
# Speed: 2.5ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 73.4ms
# Speed: 2.8ms preprocess, 73.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 1 person, 89.2ms
# Speed: 3.8ms preprocess, 89.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 72.3ms
# Speed: 2.7ms preprocess, 72.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 75.2ms
# Speed: 2.0ms preprocess, 75.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 75.7ms
# Speed: 3.4ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 74.9ms
# Speed: 3.2ms preprocess, 74.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 1 person, 74.7ms
# Speed: 2.0ms preprocess, 74.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 74.3ms
# Speed: 1.9ms preprocess, 74.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 71.6ms
# Speed: 2.3ms preprocess, 71.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 72.0ms
# Speed: 2.3ms preprocess, 72.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 74.3ms
# Speed: 4.3ms preprocess, 74.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 71.4ms
# Speed: 3.3ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.1ms
# Speed: 3.1ms preprocess, 71.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.5ms
# Speed: 3.4ms preprocess, 71.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.3ms
# Speed: 2.1ms preprocess, 72.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.8ms
# Speed: 3.0ms preprocess, 73.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.1ms
# Speed: 3.5ms preprocess, 73.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.7ms
# Speed: 2.7ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 1 handbag, 69.9ms
# Speed: 3.0ms preprocess, 69.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.0ms
# Speed: 2.5ms preprocess, 73.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.9ms
# Speed: 2.9ms preprocess, 71.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.6ms
# Speed: 2.5ms preprocess, 71.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.3ms
# Speed: 3.5ms preprocess, 71.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 1 person, 1 handbag, 80.2ms
# Speed: 2.3ms preprocess, 80.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.2ms
# Speed: 2.0ms preprocess, 73.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 89.8ms
# Speed: 3.7ms preprocess, 89.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 73.7ms
# Speed: 4.7ms preprocess, 73.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 71.4ms
# Speed: 4.7ms preprocess, 71.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 71.2ms
# Speed: 2.4ms preprocess, 71.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 71.1ms
# Speed: 2.3ms preprocess, 71.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.7ms
# Speed: 2.7ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.2ms
# Speed: 2.7ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.9ms
# Speed: 3.3ms preprocess, 71.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 74.3ms
# Speed: 2.7ms preprocess, 74.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.7ms
# Speed: 3.4ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 80.4ms
# Speed: 2.7ms preprocess, 80.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 74.0ms
# Speed: 3.6ms preprocess, 74.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 backpack, 76.5ms
# Speed: 2.4ms preprocess, 76.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 backpack, 70.7ms
# Speed: 3.6ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 backpack, 74.4ms
# Speed: 2.2ms preprocess, 74.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 1 person, 1 backpack, 70.0ms
# Speed: 4.8ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 backpack, 68.7ms
# Speed: 4.0ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 74.1ms
# Speed: 2.3ms preprocess, 74.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 1 handbag, 79.2ms
# Speed: 2.2ms preprocess, 79.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 1 backpack, 73.1ms
# Speed: 2.1ms preprocess, 73.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.9ms
# Speed: 2.7ms preprocess, 72.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.7ms
# Speed: 2.5ms preprocess, 71.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 90.7ms
# Speed: 4.2ms preprocess, 90.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 backpack, 76.3ms
# Speed: 2.8ms preprocess, 76.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 backpack, 71.8ms
# Speed: 2.1ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.8ms
# Speed: 2.8ms preprocess, 73.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.6ms
# Speed: 3.1ms preprocess, 72.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.1ms
# Speed: 2.3ms preprocess, 70.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.0ms
# Speed: 2.6ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 74.6ms
# Speed: 2.2ms preprocess, 74.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 68.9ms
# Speed: 2.3ms preprocess, 68.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.7ms
# Speed: 3.3ms preprocess, 72.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 63ms/step
#
# 0: 384x640 1 person, 1 handbag, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.7ms
# Speed: 2.1ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.2ms
# Speed: 2.5ms preprocess, 71.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 1 person, 1 handbag, 74.6ms
# Speed: 3.6ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.3ms
# Speed: 2.6ms preprocess, 71.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.2ms
# Speed: 2.5ms preprocess, 72.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.6ms
# Speed: 2.9ms preprocess, 71.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 64ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.9ms
# Speed: 3.2ms preprocess, 73.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 58ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.0ms
# Speed: 2.6ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 1 person, 1 handbag, 76.1ms
# Speed: 3.1ms preprocess, 76.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.8ms
# Speed: 2.9ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.1ms
# Speed: 2.5ms preprocess, 73.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 73.6ms
# Speed: 3.3ms preprocess, 73.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 69ms/step
#
# 0: 384x640 1 person, 71.3ms
# Speed: 2.5ms preprocess, 71.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 73.9ms
# Speed: 2.7ms preprocess, 73.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 69.3ms
# Speed: 2.2ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.8ms
# Speed: 2.8ms preprocess, 72.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 59ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.8ms
# Speed: 2.4ms preprocess, 70.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.1ms
# Speed: 3.6ms preprocess, 72.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.3ms
# Speed: 2.4ms preprocess, 72.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.5ms
# Speed: 2.7ms preprocess, 73.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 70.4ms
# Speed: 3.2ms preprocess, 70.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.7ms
# Speed: 2.4ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
#
# 0: 384x640 1 person, 1 handbag, 75.5ms
# Speed: 2.1ms preprocess, 75.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 73.0ms
# Speed: 4.1ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 67ms/step
#
# 0: 384x640 1 person, 1 handbag, 93.3ms
# Speed: 2.9ms preprocess, 93.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 68ms/step
#
# 0: 384x640 1 person, 1 handbag, 93.1ms
# Speed: 2.8ms preprocess, 93.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 66ms/step
#
# 0: 384x640 1 person, 1 handbag, 81.2ms
# Speed: 3.8ms preprocess, 81.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 66ms/step
#
# 0: 384x640 1 person, 90.5ms
# Speed: 2.4ms preprocess, 90.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 72ms/step
#
# 0: 384x640 1 person, 80.7ms
# Speed: 2.4ms preprocess, 80.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 1 person, 81.0ms
# Speed: 3.7ms preprocess, 81.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 72.2ms
# Speed: 1.9ms preprocess, 72.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 75.1ms
# Speed: 3.6ms preprocess, 75.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 1 person, 1 handbag, 91.1ms
# Speed: 4.0ms preprocess, 91.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 65ms/step
#
# 0: 384x640 1 person, 1 handbag, 74.9ms
# Speed: 2.5ms preprocess, 74.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.1ms
# Speed: 2.5ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 60ms/step
#
# 0: 384x640 1 person, 1 handbag, 71.1ms
# Speed: 2.8ms preprocess, 71.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 62ms/step
#
# 0: 384x640 1 person, 1 handbag, 72.0ms
# Speed: 2.4ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 61ms/step
# Fin del video o error en la lectura del frame.
