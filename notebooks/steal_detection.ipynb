# %% [markdown]
# ### Nota: El modelo solo funciona con tensorflow y keras 2.15, para hacer su instalación se debe tener Python 3.9

# %%
import os
from tensorflow.keras.models import load_model
from collections import defaultdict
import cv2
import numpy as np
import time
import json
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors
from collections import deque
# Out:
# WARNING:tensorflow:From c:\Users\JOSLLE\Documents\Proyectos\CencoMall\.conda\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
class Person:
    def __init__(self, id, x1, y1, x2, y2):
        self.id = id
        self.x1 = x1
        self.y1 = y1
        self.x2 = x2
        self.y2 = y2
        self.thief = False  # Indica si la persona es sospechosa de robo
        self.zones = list()

    def set_thief_status(self, status: bool):
        """Actualizar estado de sospecha de la persona."""
        self.thief = status

    def get_color(self):
        """Devuelve el color correspondiente a la persona según su estado."""
        return (0, 0, 255) if self.thief else (0, 255, 0)

    def draw(self, frame):
        """Dibuja un rectángulo alrededor de la persona."""
        cv2.rectangle(frame, (self.x1, self.y1), (self.x2, self.y2), self.get_color(), 2)
        label = "Ladrón" if self.thief else "Persona"
        cv2.putText(frame, label, (self.x1, self.y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, self.get_color(), 2)

# %%
class YoloDetector:
    def __init__(self, yolo_model, steal_model, confidence_threshold=0.7, video_path="video.mp4", 
                 individual_persons=False, output_video_path="output_video.mp4",
                 visualization=True):
        
        self.visualization = visualization
        self.confidence_threshold = confidence_threshold
        self.video_path = video_path
        self.output_video_path = output_video_path  # Ruta para guardar el video procesado
        self.individual_persons = individual_persons
        self.people = list()
        self.zones = list()

        self.IMG_SIZE = (90, 90)
        self.SEQUENCE_LENGTH = 160  

        self.frame_queue = deque(maxlen=self.SEQUENCE_LENGTH)
        self.person_states = defaultdict(lambda: {"is_thief": False, "frames_since_last_detection": 0})  # Almacenar estado de las personas

        # Cargar modelo YOLO
        self.yolo_model = YOLO(yolo_model)
        # Cargar modelo LRCN para robos
        self.steal_model = load_model(steal_model)

        self.detect_thief()

    def preprocess_frame(self, frame):
        """Preprocesa un frame para que sea compatible con el modelo."""
        frame = cv2.resize(frame, self.IMG_SIZE)  # Redimensionar a 90x90
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convertir a escala de grises
        frame = frame / 255.0  # Normalización
        frame = np.expand_dims(frame, axis=-1)  # Añadir canal de profundidad
        return frame

    def predict_thief(self, frame):
        input_sequence = np.expand_dims(np.array(frame), axis=0)
        predictions = self.steal_model.predict(input_sequence)

        # Obtenemos el indice del mayor valor de la predicción
        prediction = np.argmax(predictions)
        confidence = predictions[0][prediction]

        return prediction, confidence

    def detect_thief(self):
        cap = cv2.VideoCapture(self.video_path)

        # Obtener las propiedades del video (como el FPS y la resolución)
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = cap.get(cv2.CAP_PROP_FPS)

        # Configurar VideoWriter para guardar el video de salida
        fourcc = cv2.VideoWriter_fourcc(*"XVID")  # Usar códec XVID
        out = cv2.VideoWriter(self.output_video_path, fourcc, fps, (width, height))

        while True:
            ret, frame = cap.read()

            if not ret or frame is None:
                print("Fin del video.")
                break

            annotator = Annotator(frame, line_width=2)
            results = self.yolo_model.track(frame, persist=True)

            if results[0].boxes.id is not None:
                boxes = results[0].boxes.xyxy.cpu().numpy()
                confs = results[0].boxes.conf.cpu().numpy()
                class_ids = results[0].boxes.cls.cpu().numpy()
                track_ids = results[0].boxes.id.int().cpu().tolist()
                
                current_frame_people = set()

                for box, conf, class_id, track_id in zip(boxes, confs, class_ids, track_ids):
                    if int(class_id) == 0:  # Detectar solo personas
                        current_frame_people.add(track_id)  # Agregar a las personas en el frame actual

                        centroid_x = int((box[0] + box[2]) / 2)
                        centroid_y = int((box[1] + box[3]) / 2)
                        cv2.circle(frame, (centroid_x, centroid_y), 5, (0, 0, 255), -1)

                        if self.individual_persons:
                            # Extraer coordenadas del bounding box
                            x1, y1, x2, y2 = map(int, box)  # Convertir a enteros

                            # Asegurar que las coordenadas estén dentro del tamaño del frame
                            x1, y1 = max(0, x1), max(0, y1)
                            x2, y2 = min(width, x2), min(height, y2)

                            # Recortar la región de la persona detectada
                            person_crop = frame[y1:y2, x1:x2]

                            processed_frame = self.preprocess_frame(person_crop)
                            self.frame_queue.append(processed_frame)
                            
                            if len(self.frame_queue) == self.SEQUENCE_LENGTH:
                                prediction, confidence = self.predict_thief(self.frame_queue)
                                self.frame_queue.clear()

                                if str(prediction) == "0" and confidence > self.confidence_threshold:
                                    self.person_states[track_id]["is_thief"] = True  # Marcar como ladrón
                                    self.person_states[track_id]["frames_since_last_detection"] = 0  # Reiniciar contador
                                else:
                                    self.person_states[track_id]["frames_since_last_detection"] += 1  # Incrementar contador

                                # Si no se detecta como ladrón por varios frames, se deja de considerar como ladrón
                                if self.person_states[track_id]["frames_since_last_detection"] > 30:  # Ajusta este valor según sea necesario
                                    self.person_states[track_id]["is_thief"] = False

                        # Si la persona es un ladrón, dibujar el label
                        if self.person_states[track_id]["is_thief"]:
                            label = "Ladron"
                            annotator.box_label(box, label, color=(0, 0, 255))

                # Limpiar estados de personas que ya no están en el frame
                for track_id in list(self.person_states.keys()):
                    if track_id not in current_frame_people:
                        del self.person_states[track_id]

            # Guardar el frame procesado en el video de salida
            out.write(frame)
            
            if self.visualization:
                cv2.imshow("object-detection-tracking", frame)

            if cv2.waitKey(1) & 0xFF == ord("q"):
                break

        cap.release()
        out.release()  # Liberar el VideoWriter
        cv2.destroyAllWindows()

# %%
yolo_model = "../src/models/yolo11x.pt"
steal_model = "../src/models/lrcn_160S_90_90Q.h5"
video_path = '../tests/mall_sim.mp4'
output_video_path = "../outputs/steal_output_2.mp4"
individual_persons = True
confidence_threshold = 0.9
visualization = True

detector = YoloDetector(yolo_model, steal_model, confidence_threshold, video_path, individual_persons, output_video_path, visualization)
# Out:
# 0: 384x640 1 person, 441.2ms
# Speed: 15.0ms preprocess, 441.2ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 447.7ms
# Speed: 1.8ms preprocess, 447.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 416.2ms
# Speed: 1.9ms preprocess, 416.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 418.4ms
# Speed: 1.0ms preprocess, 418.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 423.2ms
# Speed: 3.1ms preprocess, 423.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 434.2ms
# Speed: 0.0ms preprocess, 434.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.2ms
# Speed: 2.4ms preprocess, 396.2ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 401.5ms
# Speed: 0.0ms preprocess, 401.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.4ms
# Speed: 0.0ms preprocess, 404.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.5ms
# Speed: 1.0ms preprocess, 410.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 414.3ms
# Speed: 1.0ms preprocess, 414.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.2ms
# Speed: 0.0ms preprocess, 410.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 424.8ms
# Speed: 0.0ms preprocess, 424.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 416.4ms
# Speed: 3.6ms preprocess, 416.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 407.7ms
# Speed: 2.0ms preprocess, 407.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 422.4ms
# Speed: 1.5ms preprocess, 422.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 419.4ms
# Speed: 0.0ms preprocess, 419.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 414.8ms
# Speed: 1.0ms preprocess, 414.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 416.4ms
# Speed: 0.0ms preprocess, 416.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 414.8ms
# Speed: 1.2ms preprocess, 414.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 420.7ms
# Speed: 0.0ms preprocess, 420.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 421.1ms
# Speed: 1.0ms preprocess, 421.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.5ms
# Speed: 1.5ms preprocess, 405.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 400.7ms
# Speed: 2.0ms preprocess, 400.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.6ms
# Speed: 0.0ms preprocess, 410.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 416.7ms
# Speed: 1.8ms preprocess, 416.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 402.3ms
# Speed: 0.0ms preprocess, 402.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 413.5ms
# Speed: 0.0ms preprocess, 413.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 411.2ms
# Speed: 1.0ms preprocess, 411.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.5ms
# Speed: 1.0ms preprocess, 410.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 422.1ms
# Speed: 3.1ms preprocess, 422.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.0ms
# Speed: 1.0ms preprocess, 406.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.9ms
# Speed: 1.4ms preprocess, 405.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 415.5ms
# Speed: 1.0ms preprocess, 415.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 418.9ms
# Speed: 2.5ms preprocess, 418.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 383.7ms
# Speed: 1.4ms preprocess, 383.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 421.3ms
# Speed: 2.1ms preprocess, 421.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 407.1ms
# Speed: 0.5ms preprocess, 407.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.8ms
# Speed: 1.3ms preprocess, 409.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.7ms
# Speed: 1.0ms preprocess, 410.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.5ms
# Speed: 0.0ms preprocess, 406.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 401.0ms
# Speed: 2.0ms preprocess, 401.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 417.4ms
# Speed: 0.0ms preprocess, 417.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.4ms
# Speed: 2.1ms preprocess, 396.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 415.4ms
# Speed: 0.0ms preprocess, 415.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 411.6ms
# Speed: 5.4ms preprocess, 411.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.2ms
# Speed: 0.8ms preprocess, 410.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 409.2ms
# Speed: 0.0ms preprocess, 409.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 418.3ms
# Speed: 1.0ms preprocess, 418.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 406.1ms
# Speed: 1.0ms preprocess, 406.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 413.5ms
# Speed: 2.8ms preprocess, 413.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 396.8ms
# Speed: 1.6ms preprocess, 396.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 407.1ms
# Speed: 1.5ms preprocess, 407.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 411.4ms
# Speed: 0.5ms preprocess, 411.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 408.7ms
# Speed: 0.0ms preprocess, 408.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 413.4ms
# Speed: 0.0ms preprocess, 413.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 407.5ms
# Speed: 1.7ms preprocess, 407.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 399.6ms
# Speed: 1.4ms preprocess, 399.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 401.5ms
# Speed: 0.0ms preprocess, 401.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 408.8ms
# Speed: 0.5ms preprocess, 408.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 409.8ms
# Speed: 1.1ms preprocess, 409.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 410.2ms
# Speed: 0.9ms preprocess, 410.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 406.3ms
# Speed: 1.0ms preprocess, 406.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 405.6ms
# Speed: 2.0ms preprocess, 405.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 427.6ms
# Speed: 2.4ms preprocess, 427.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 415.8ms
# Speed: 1.5ms preprocess, 415.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 422.6ms
# Speed: 0.0ms preprocess, 422.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 424.7ms
# Speed: 1.0ms preprocess, 424.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 429.0ms
# Speed: 3.0ms preprocess, 429.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 428.6ms
# Speed: 0.0ms preprocess, 428.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 434.5ms
# Speed: 0.0ms preprocess, 434.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 426.3ms
# Speed: 1.5ms preprocess, 426.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 437.6ms
# Speed: 1.0ms preprocess, 437.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 442.9ms
# Speed: 1.6ms preprocess, 442.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 429.9ms
# Speed: 1.3ms preprocess, 429.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 457.2ms
# Speed: 0.0ms preprocess, 457.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 438.4ms
# Speed: 2.2ms preprocess, 438.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 446.8ms
# Speed: 1.2ms preprocess, 446.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 427.0ms
# Speed: 1.6ms preprocess, 427.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 423.8ms
# Speed: 1.0ms preprocess, 423.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 422.1ms
# Speed: 1.7ms preprocess, 422.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 423.9ms
# Speed: 1.9ms preprocess, 423.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 428.5ms
# Speed: 3.2ms preprocess, 428.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 420.7ms
# Speed: 1.5ms preprocess, 420.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 412.0ms
# Speed: 1.1ms preprocess, 412.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 435.9ms
# Speed: 1.0ms preprocess, 435.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 427.0ms
# Speed: 0.6ms preprocess, 427.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 431.5ms
# Speed: 0.0ms preprocess, 431.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 429.1ms
# Speed: 1.0ms preprocess, 429.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 420.9ms
# Speed: 2.0ms preprocess, 420.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 438.5ms
# Speed: 1.0ms preprocess, 438.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 435.2ms
# Speed: 2.0ms preprocess, 435.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 448.7ms
# Speed: 1.5ms preprocess, 448.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 438.2ms
# Speed: 0.0ms preprocess, 438.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 433.5ms
# Speed: 1.0ms preprocess, 433.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 428.7ms
# Speed: 2.1ms preprocess, 428.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 426.3ms
# Speed: 2.1ms preprocess, 426.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 434.3ms
# Speed: 1.2ms preprocess, 434.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 437.6ms
# Speed: 0.6ms preprocess, 437.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 427.1ms
# Speed: 1.1ms preprocess, 427.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 428.1ms
# Speed: 1.4ms preprocess, 428.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 418.8ms
# Speed: 1.1ms preprocess, 418.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 418.7ms
# Speed: 1.0ms preprocess, 418.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 434.0ms
# Speed: 1.4ms preprocess, 434.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 1 cell phone, 426.9ms
# Speed: 1.1ms preprocess, 426.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 1 cell phone, 425.3ms
# Speed: 1.8ms preprocess, 425.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 1 cell phone, 417.1ms
# Speed: 2.0ms preprocess, 417.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 1 cell phone, 425.6ms
# Speed: 1.9ms preprocess, 425.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 413.7ms
# Speed: 1.7ms preprocess, 413.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 427.6ms
# Speed: 0.0ms preprocess, 427.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 419.0ms
# Speed: 1.9ms preprocess, 419.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 433.4ms
# Speed: 0.6ms preprocess, 433.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 433.5ms
# Speed: 0.0ms preprocess, 433.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 423.9ms
# Speed: 0.0ms preprocess, 423.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 434.0ms
# Speed: 1.7ms preprocess, 434.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 428.1ms
# Speed: 1.8ms preprocess, 428.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 419.8ms
# Speed: 1.6ms preprocess, 419.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 432.5ms
# Speed: 0.0ms preprocess, 432.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 415.9ms
# Speed: 2.2ms preprocess, 415.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 419.5ms
# Speed: 1.1ms preprocess, 419.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 412.0ms
# Speed: 1.0ms preprocess, 412.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 421.8ms
# Speed: 3.1ms preprocess, 421.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 425.6ms
# Speed: 2.5ms preprocess, 425.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 1s 683ms/step
#
# 0: 384x640 2 persons, 422.3ms
# Speed: 1.5ms preprocess, 422.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 421.7ms
# Speed: 0.0ms preprocess, 421.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 421.0ms
# Speed: 4.7ms preprocess, 421.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 432.3ms
# Speed: 1.0ms preprocess, 432.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 419.5ms
# Speed: 1.1ms preprocess, 419.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 437.2ms
# Speed: 1.5ms preprocess, 437.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 452.0ms
# Speed: 3.1ms preprocess, 452.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 427.5ms
# Speed: 1.0ms preprocess, 427.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 451.6ms
# Speed: 3.8ms preprocess, 451.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 421.5ms
# Speed: 1.3ms preprocess, 421.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 422.8ms
# Speed: 1.6ms preprocess, 422.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 415.7ms
# Speed: 0.8ms preprocess, 415.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 421.3ms
# Speed: 1.5ms preprocess, 421.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 419.1ms
# Speed: 1.0ms preprocess, 419.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 428.6ms
# Speed: 0.6ms preprocess, 428.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 421.1ms
# Speed: 1.9ms preprocess, 421.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 424.8ms
# Speed: 0.0ms preprocess, 424.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 420.7ms
# Speed: 1.6ms preprocess, 420.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 414.4ms
# Speed: 1.0ms preprocess, 414.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 439.2ms
# Speed: 1.0ms preprocess, 439.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 465.4ms
# Speed: 1.7ms preprocess, 465.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 467.3ms
# Speed: 0.0ms preprocess, 467.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 459.8ms
# Speed: 2.0ms preprocess, 459.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 454.4ms
# Speed: 1.7ms preprocess, 454.4ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 455.8ms
# Speed: 1.3ms preprocess, 455.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 441.0ms
# Speed: 1.5ms preprocess, 441.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 422.6ms
# Speed: 1.0ms preprocess, 422.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cell phone, 425.3ms
# Speed: 0.8ms preprocess, 425.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 cell phone, 409.9ms
# Speed: 1.1ms preprocess, 409.9ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 cell phone, 428.2ms
# Speed: 1.8ms preprocess, 428.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 cell phone, 414.8ms
# Speed: 0.6ms preprocess, 414.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 cell phone, 421.2ms
# Speed: 0.9ms preprocess, 421.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 cell phone, 424.7ms
# Speed: 0.0ms preprocess, 424.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 cell phone, 418.0ms
# Speed: 1.7ms preprocess, 418.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 cell phone, 431.3ms
# Speed: 1.7ms preprocess, 431.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 cell phone, 429.1ms
# Speed: 1.2ms preprocess, 429.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 1 cell phone, 420.9ms
# Speed: 1.6ms preprocess, 420.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 1 cell phone, 474.3ms
# Speed: 1.6ms preprocess, 474.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 1 cell phone, 423.7ms
# Speed: 2.0ms preprocess, 423.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 1 cell phone, 441.8ms
# Speed: 1.2ms preprocess, 441.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 1 cell phone, 424.7ms
# Speed: 1.2ms preprocess, 424.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 425.3ms
# Speed: 1.5ms preprocess, 425.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 426.7ms
# Speed: 0.5ms preprocess, 426.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 433.3ms
# Speed: 2.1ms preprocess, 433.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 421.3ms
# Speed: 1.8ms preprocess, 421.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 442.3ms
# Speed: 2.0ms preprocess, 442.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 416.7ms
# Speed: 1.5ms preprocess, 416.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 1 remote, 423.7ms
# Speed: 1.4ms preprocess, 423.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 remote, 422.6ms
# Speed: 2.0ms preprocess, 422.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 remote, 434.1ms
# Speed: 1.5ms preprocess, 434.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 425.6ms
# Speed: 2.0ms preprocess, 425.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 424.4ms
# Speed: 1.9ms preprocess, 424.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 remote, 425.0ms
# Speed: 2.4ms preprocess, 425.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 remote, 417.0ms
# Speed: 1.5ms preprocess, 417.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 remote, 422.1ms
# Speed: 1.0ms preprocess, 422.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 remote, 423.7ms
# Speed: 1.5ms preprocess, 423.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 remote, 423.1ms
# Speed: 1.0ms preprocess, 423.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 remote, 422.8ms
# Speed: 1.0ms preprocess, 422.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 remote, 416.5ms
# Speed: 1.8ms preprocess, 416.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 remote, 420.7ms
# Speed: 1.3ms preprocess, 420.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 remote, 430.8ms
# Speed: 1.0ms preprocess, 430.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 413.1ms
# Speed: 2.3ms preprocess, 413.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 409.9ms
# Speed: 5.0ms preprocess, 409.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 411.6ms
# Speed: 2.9ms preprocess, 411.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 436.7ms
# Speed: 0.0ms preprocess, 436.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 433.6ms
# Speed: 0.9ms preprocess, 433.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 411.7ms
# Speed: 1.7ms preprocess, 411.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 427.9ms
# Speed: 1.3ms preprocess, 427.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 420.3ms
# Speed: 1.2ms preprocess, 420.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 420.1ms
# Speed: 1.0ms preprocess, 420.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 422.2ms
# Speed: 0.0ms preprocess, 422.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 419.2ms
# Speed: 0.0ms preprocess, 419.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 414.1ms
# Speed: 2.7ms preprocess, 414.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 433.8ms
# Speed: 1.1ms preprocess, 433.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 426.3ms
# Speed: 2.3ms preprocess, 426.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 427.7ms
# Speed: 1.0ms preprocess, 427.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 416.0ms
# Speed: 1.2ms preprocess, 416.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 430.3ms
# Speed: 1.4ms preprocess, 430.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 415.3ms
# Speed: 4.4ms preprocess, 415.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 1 remote, 421.6ms
# Speed: 1.7ms preprocess, 421.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 432.0ms
# Speed: 0.7ms preprocess, 432.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 420.2ms
# Speed: 1.5ms preprocess, 420.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 424.1ms
# Speed: 1.8ms preprocess, 424.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 432.3ms
# Speed: 1.1ms preprocess, 432.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 433.9ms
# Speed: 0.5ms preprocess, 433.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 427.5ms
# Speed: 2.0ms preprocess, 427.5ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 424.2ms
# Speed: 1.8ms preprocess, 424.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 406.2ms
# Speed: 0.9ms preprocess, 406.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 419.4ms
# Speed: 1.0ms preprocess, 419.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 410.9ms
# Speed: 1.9ms preprocess, 410.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 418.6ms
# Speed: 1.4ms preprocess, 418.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 427.6ms
# Speed: 1.5ms preprocess, 427.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 426.7ms
# Speed: 3.6ms preprocess, 426.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 418.8ms
# Speed: 2.0ms preprocess, 418.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 425.3ms
# Speed: 1.7ms preprocess, 425.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 421.1ms
# Speed: 1.5ms preprocess, 421.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 424.9ms
# Speed: 1.5ms preprocess, 424.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 423.9ms
# Speed: 0.0ms preprocess, 423.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 397.1ms
# Speed: 1.5ms preprocess, 397.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 423.9ms
# Speed: 1.0ms preprocess, 423.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 419.1ms
# Speed: 1.6ms preprocess, 419.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 4 persons, 1 tv, 394.6ms
# Speed: 3.4ms preprocess, 394.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 422.9ms
# Speed: 1.7ms preprocess, 422.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 429.2ms
# Speed: 5.4ms preprocess, 429.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 421.6ms
# Speed: 1.5ms preprocess, 421.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 430.0ms
# Speed: 1.2ms preprocess, 430.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 436.0ms
# Speed: 1.4ms preprocess, 436.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 417.9ms
# Speed: 2.2ms preprocess, 417.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 416.1ms
# Speed: 2.4ms preprocess, 416.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 422.5ms
# Speed: 0.0ms preprocess, 422.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 426.7ms
# Speed: 2.6ms preprocess, 426.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 433.1ms
# Speed: 1.2ms preprocess, 433.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 425.7ms
# Speed: 1.0ms preprocess, 425.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 432.6ms
# Speed: 1.3ms preprocess, 432.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 432.9ms
# Speed: 0.7ms preprocess, 432.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 424.4ms
# Speed: 1.1ms preprocess, 424.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 430.9ms
# Speed: 0.0ms preprocess, 430.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 424.2ms
# Speed: 1.4ms preprocess, 424.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 429.3ms
# Speed: 2.0ms preprocess, 429.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 419.8ms
# Speed: 1.1ms preprocess, 419.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 427.3ms
# Speed: 2.0ms preprocess, 427.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 426.0ms
# Speed: 1.8ms preprocess, 426.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 432.5ms
# Speed: 2.1ms preprocess, 432.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 420.1ms
# Speed: 1.1ms preprocess, 420.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 426.8ms
# Speed: 1.5ms preprocess, 426.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 414.6ms
# Speed: 0.0ms preprocess, 414.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 tv, 420.9ms
# Speed: 1.0ms preprocess, 420.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 419.6ms
# Speed: 1.6ms preprocess, 419.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 tv, 430.1ms
# Speed: 0.0ms preprocess, 430.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 428.4ms
# Speed: 1.1ms preprocess, 428.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 415.8ms
# Speed: 1.5ms preprocess, 415.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 421.8ms
# Speed: 1.9ms preprocess, 421.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 tv, 424.1ms
# Speed: 1.5ms preprocess, 424.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 420.4ms
# Speed: 2.3ms preprocess, 420.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 419.7ms
# Speed: 0.8ms preprocess, 419.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 417.7ms
# Speed: 1.0ms preprocess, 417.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 417.4ms
# Speed: 1.2ms preprocess, 417.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 433.8ms
# Speed: 2.7ms preprocess, 433.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 462.3ms
# Speed: 1.2ms preprocess, 462.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 422.6ms
# Speed: 2.0ms preprocess, 422.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 420.2ms
# Speed: 1.0ms preprocess, 420.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 49ms/step
#
# 0: 384x640 5 persons, 417.5ms
# Speed: 1.4ms preprocess, 417.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 422.7ms
# Speed: 1.4ms preprocess, 422.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 421.7ms
# Speed: 2.0ms preprocess, 421.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 418.5ms
# Speed: 1.7ms preprocess, 418.5ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 434.2ms
# Speed: 5.1ms preprocess, 434.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 421.3ms
# Speed: 2.3ms preprocess, 421.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 412.7ms
# Speed: 6.6ms preprocess, 412.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 426.0ms
# Speed: 2.2ms preprocess, 426.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 425.3ms
# Speed: 2.3ms preprocess, 425.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 425.0ms
# Speed: 2.0ms preprocess, 425.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 404.2ms
# Speed: 2.2ms preprocess, 404.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 413.3ms
# Speed: 1.7ms preprocess, 413.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 419.6ms
# Speed: 2.2ms preprocess, 419.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 419.5ms
# Speed: 1.5ms preprocess, 419.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 420.3ms
# Speed: 1.9ms preprocess, 420.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 428.4ms
# Speed: 4.3ms preprocess, 428.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 425.3ms
# Speed: 2.0ms preprocess, 425.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 422.3ms
# Speed: 2.3ms preprocess, 422.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 423.7ms
# Speed: 1.2ms preprocess, 423.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 430.4ms
# Speed: 1.4ms preprocess, 430.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 394.8ms
# Speed: 0.0ms preprocess, 394.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 427.6ms
# Speed: 1.5ms preprocess, 427.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 426.7ms
# Speed: 1.0ms preprocess, 426.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 425.1ms
# Speed: 0.9ms preprocess, 425.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 413.4ms
# Speed: 1.5ms preprocess, 413.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 416.2ms
# Speed: 1.2ms preprocess, 416.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 413.5ms
# Speed: 3.2ms preprocess, 413.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 429.3ms
# Speed: 1.9ms preprocess, 429.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 429.9ms
# Speed: 0.9ms preprocess, 429.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 426.1ms
# Speed: 1.4ms preprocess, 426.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 423.6ms
# Speed: 1.7ms preprocess, 423.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 425.5ms
# Speed: 1.0ms preprocess, 425.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 427.8ms
# Speed: 2.3ms preprocess, 427.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 53ms/step
#
# 0: 384x640 6 persons, 408.0ms
# Speed: 0.0ms preprocess, 408.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 447.8ms
# Speed: 2.2ms preprocess, 447.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 402.1ms
# Speed: 1.0ms preprocess, 402.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 461.8ms
# Speed: 0.6ms preprocess, 461.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 480.6ms
# Speed: 2.0ms preprocess, 480.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 466.0ms
# Speed: 1.0ms preprocess, 466.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 448.1ms
# Speed: 1.0ms preprocess, 448.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 436.8ms
# Speed: 1.9ms preprocess, 436.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 432.0ms
# Speed: 1.5ms preprocess, 432.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 455.7ms
# Speed: 2.7ms preprocess, 455.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 424.4ms
# Speed: 2.0ms preprocess, 424.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 420.5ms
# Speed: 0.0ms preprocess, 420.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 423.4ms
# Speed: 0.0ms preprocess, 423.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 423.5ms
# Speed: 1.9ms preprocess, 423.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 432.0ms
# Speed: 1.1ms preprocess, 432.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 422.1ms
# Speed: 1.3ms preprocess, 422.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 418.5ms
# Speed: 1.4ms preprocess, 418.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 416.9ms
# Speed: 1.9ms preprocess, 416.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 424.0ms
# Speed: 1.8ms preprocess, 424.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 419.5ms
# Speed: 1.4ms preprocess, 419.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 422.4ms
# Speed: 0.5ms preprocess, 422.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 415.3ms
# Speed: 1.0ms preprocess, 415.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 421.7ms
# Speed: 2.1ms preprocess, 421.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 427.4ms
# Speed: 2.3ms preprocess, 427.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 428.1ms
# Speed: 0.0ms preprocess, 428.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 421.0ms
# Speed: 1.9ms preprocess, 421.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 41ms/step
#
# 0: 384x640 6 persons, 1 tv, 415.9ms
# Speed: 1.6ms preprocess, 415.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 tv, 424.7ms
# Speed: 5.3ms preprocess, 424.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 412.8ms
# Speed: 0.8ms preprocess, 412.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 416.7ms
# Speed: 3.1ms preprocess, 416.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 421.1ms
# Speed: 1.3ms preprocess, 421.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 428.9ms
# Speed: 2.2ms preprocess, 428.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 418.7ms
# Speed: 0.5ms preprocess, 418.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 411.5ms
# Speed: 3.0ms preprocess, 411.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 425.0ms
# Speed: 1.6ms preprocess, 425.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 416.1ms
# Speed: 1.3ms preprocess, 416.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 426.8ms
# Speed: 1.9ms preprocess, 426.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 425.7ms
# Speed: 2.0ms preprocess, 425.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 418.9ms
# Speed: 1.7ms preprocess, 418.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 429.5ms
# Speed: 2.2ms preprocess, 429.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 420.5ms
# Speed: 1.8ms preprocess, 420.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 423.3ms
# Speed: 0.7ms preprocess, 423.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 425.3ms
# Speed: 1.6ms preprocess, 425.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 1 tv, 433.1ms
# Speed: 0.0ms preprocess, 433.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 1 tv, 425.2ms
# Speed: 0.0ms preprocess, 425.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 1 tv, 417.9ms
# Speed: 1.0ms preprocess, 417.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 handbag, 1 tv, 421.9ms
# Speed: 1.0ms preprocess, 421.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 tv, 418.5ms
# Speed: 2.1ms preprocess, 418.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 433.1ms
# Speed: 0.5ms preprocess, 433.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 425.5ms
# Speed: 5.5ms preprocess, 425.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 422.9ms
# Speed: 2.6ms preprocess, 422.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 434.3ms
# Speed: 0.5ms preprocess, 434.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 433.1ms
# Speed: 0.9ms preprocess, 433.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 422.5ms
# Speed: 1.1ms preprocess, 422.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 413.1ms
# Speed: 1.6ms preprocess, 413.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 442.5ms
# Speed: 1.2ms preprocess, 442.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 430.5ms
# Speed: 1.8ms preprocess, 430.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 433.8ms
# Speed: 2.0ms preprocess, 433.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 45ms/step
#
# 0: 384x640 6 persons, 414.8ms
# ...
#
# 0: 384x640 2 persons, 466.7ms
# Speed: 1.3ms preprocess, 466.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 474.7ms
# Speed: 0.0ms preprocess, 474.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 467.0ms
# Speed: 3.2ms preprocess, 467.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 475.5ms
# Speed: 1.0ms preprocess, 475.5ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 459.9ms
# Speed: 3.4ms preprocess, 459.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 560.4ms
# Speed: 1.9ms preprocess, 560.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 465.0ms
# Speed: 1.5ms preprocess, 465.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 525.7ms
# Speed: 1.8ms preprocess, 525.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 489.9ms
# Speed: 2.6ms preprocess, 489.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 541.0ms
# Speed: 0.8ms preprocess, 541.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 556.3ms
# Speed: 1.8ms preprocess, 556.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 561.2ms
# Speed: 3.1ms preprocess, 561.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 521.5ms
# Speed: 1.0ms preprocess, 521.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 524.1ms
# Speed: 1.0ms preprocess, 524.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 578.8ms
# Speed: 0.3ms preprocess, 578.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 591.1ms
# Speed: 1.5ms preprocess, 591.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 586.8ms
# Speed: 2.0ms preprocess, 586.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 551.7ms
# Speed: 2.0ms preprocess, 551.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 578.7ms
# Speed: 2.0ms preprocess, 578.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 556.3ms
# Speed: 1.7ms preprocess, 556.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 567.3ms
# Speed: 1.1ms preprocess, 567.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 577.2ms
# Speed: 0.0ms preprocess, 577.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 582.7ms
# Speed: 2.0ms preprocess, 582.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 588.1ms
# Speed: 2.0ms preprocess, 588.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 550.7ms
# Speed: 2.1ms preprocess, 550.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 526.5ms
# Speed: 5.0ms preprocess, 526.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 551.9ms
# Speed: 2.0ms preprocess, 551.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 498.1ms
# Speed: 0.0ms preprocess, 498.1ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 582.6ms
# Speed: 2.0ms preprocess, 582.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 560.0ms
# Speed: 1.0ms preprocess, 560.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 520.5ms
# Speed: 2.1ms preprocess, 520.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 507.6ms
# Speed: 0.0ms preprocess, 507.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 521.4ms
# Speed: 0.0ms preprocess, 521.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 510.9ms
# Speed: 3.1ms preprocess, 510.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 534.1ms
# Speed: 0.0ms preprocess, 534.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 556.0ms
# Speed: 0.0ms preprocess, 556.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 538.4ms
# Speed: 0.0ms preprocess, 538.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 550.0ms
# Speed: 0.0ms preprocess, 550.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 542.8ms
# Speed: 1.8ms preprocess, 542.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 564.7ms
# Speed: 0.7ms preprocess, 564.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 546.9ms
# Speed: 0.0ms preprocess, 546.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 556.0ms
# Speed: 1.1ms preprocess, 556.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 537.8ms
# Speed: 2.2ms preprocess, 537.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 523.8ms
# Speed: 2.0ms preprocess, 523.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 590.3ms
# Speed: 0.0ms preprocess, 590.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 582.3ms
# Speed: 3.5ms preprocess, 582.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 586.8ms
# Speed: 0.0ms preprocess, 586.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 587.0ms
# Speed: 4.4ms preprocess, 587.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 533.9ms
# Speed: 1.0ms preprocess, 533.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 529.0ms
# Speed: 1.7ms preprocess, 529.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 539.6ms
# Speed: 0.6ms preprocess, 539.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 527.7ms
# Speed: 2.0ms preprocess, 527.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 566.9ms
# Speed: 0.0ms preprocess, 566.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 572.1ms
# Speed: 2.0ms preprocess, 572.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 560.8ms
# Speed: 1.8ms preprocess, 560.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 586.3ms
# Speed: 2.0ms preprocess, 586.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 558.2ms
# Speed: 3.0ms preprocess, 558.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# 1/1 [==============================] - 0s 56ms/step
#
# 0: 384x640 2 persons, 565.0ms
# Speed: 0.0ms preprocess, 565.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 594.8ms
# Speed: 0.0ms preprocess, 594.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 570.4ms
# Speed: 1.9ms preprocess, 570.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 597.7ms
# Speed: 3.6ms preprocess, 597.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 568.2ms
# Speed: 1.1ms preprocess, 568.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 591.7ms
# Speed: 1.2ms preprocess, 591.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 571.2ms
# Speed: 0.0ms preprocess, 571.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 588.6ms
# Speed: 0.5ms preprocess, 588.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 561.1ms
# Speed: 4.7ms preprocess, 561.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 583.6ms
# Speed: 3.0ms preprocess, 583.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 559.9ms
# Speed: 0.0ms preprocess, 559.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 608.1ms
# Speed: 0.0ms preprocess, 608.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 548.0ms
# Speed: 1.5ms preprocess, 548.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 585.6ms
# Speed: 2.1ms preprocess, 585.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 579.9ms
# Speed: 0.0ms preprocess, 579.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 576.7ms
# Speed: 0.0ms preprocess, 576.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 528.7ms
# Speed: 1.1ms preprocess, 528.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 574.5ms
# Speed: 5.1ms preprocess, 574.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 613.4ms
# Speed: 3.9ms preprocess, 613.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 579.8ms
# Speed: 1.1ms preprocess, 579.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 580.8ms
# Speed: 6.3ms preprocess, 580.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 557.5ms
# Speed: 0.7ms preprocess, 557.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 580.4ms
# Speed: 0.0ms preprocess, 580.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 626.9ms
# Speed: 2.0ms preprocess, 626.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 635.4ms
# Speed: 1.0ms preprocess, 635.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 539.9ms
# Speed: 1.0ms preprocess, 539.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 577.1ms
# Speed: 1.5ms preprocess, 577.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 547.8ms
# Speed: 2.0ms preprocess, 547.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 606.0ms
# Speed: 3.0ms preprocess, 606.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 587.6ms
# Speed: 1.0ms preprocess, 587.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 577.2ms
# Speed: 1.8ms preprocess, 577.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 578.6ms
# Speed: 1.5ms preprocess, 578.6ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 617.4ms
# Speed: 3.5ms preprocess, 617.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 571.0ms
# Speed: 0.0ms preprocess, 571.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 559.1ms
# Speed: 0.0ms preprocess, 559.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 569.6ms
# Speed: 0.0ms preprocess, 569.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 581.4ms
# Speed: 1.5ms preprocess, 581.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 573.7ms
# Speed: 2.6ms preprocess, 573.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 594.7ms
# Speed: 2.0ms preprocess, 594.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 596.8ms
# Speed: 2.0ms preprocess, 596.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 546.1ms
# Speed: 2.0ms preprocess, 546.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 534.8ms
# Speed: 0.0ms preprocess, 534.8ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 554.3ms
# Speed: 2.0ms preprocess, 554.3ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 569.7ms
# Speed: 0.0ms preprocess, 569.7ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 572.0ms
# Speed: 0.0ms preprocess, 572.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 589.1ms
# Speed: 1.0ms preprocess, 589.1ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 590.6ms
# Speed: 1.9ms preprocess, 590.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 598.8ms
# Speed: 2.0ms preprocess, 598.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 558.0ms
# Speed: 1.1ms preprocess, 558.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 609.5ms
# Speed: 2.2ms preprocess, 609.5ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 583.0ms
# Speed: 0.5ms preprocess, 583.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 584.3ms
# Speed: 0.0ms preprocess, 584.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 584.1ms
# Speed: 1.5ms preprocess, 584.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 570.2ms
# Speed: 1.1ms preprocess, 570.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 602.8ms
# Speed: 2.0ms preprocess, 602.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 568.1ms
# Speed: 5.0ms preprocess, 568.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 574.0ms
# Speed: 2.0ms preprocess, 574.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 609.3ms
# Speed: 0.0ms preprocess, 609.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 583.4ms
# Speed: 2.0ms preprocess, 583.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 596.2ms
# Speed: 2.7ms preprocess, 596.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 629.2ms
# Speed: 3.0ms preprocess, 629.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 596.0ms
# Speed: 0.0ms preprocess, 596.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 589.6ms
# Speed: 1.0ms preprocess, 589.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 570.5ms
# Speed: 2.7ms preprocess, 570.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 570.4ms
# Speed: 2.4ms preprocess, 570.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 565.1ms
# Speed: 0.0ms preprocess, 565.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Fin del video.
