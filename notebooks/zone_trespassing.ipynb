# %%
import cv2
import numpy as np

def initialize_video_capture(video_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError("Error opening video file")
    return cap

def get_video_properties(cap):
    return (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),
            int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)),
            int(cap.get(cv2.CAP_PROP_FPS)))

def initialize_video_writer(output_path, fourcc, fps, width, height):
    return cv2.VideoWriter(output_path, fourcc, fps, (width, height))

def save_logs(logs_path, data):
    with open(logs_path, "a") as f:
        # Extraemos los datos del diccionario y los guardamos en el archivo
        for key, value in data.items():
            f.write(f"{key}: {value}\n")

def detect_shoplifting(frame, model, confidence_threshold=0.8):
    """
    Detecta si una persona está robando en el frame utilizando el modelo de detección de robo.
    
    Args:
        frame (numpy.ndarray): El frame de video.
        model (YOLO): El modelo YOLO para detección de robo.
        confidence_threshold (float): Umbral de confianza para considerar una detección válida.
    
    Returns:
        numpy.ndarray: El frame con las anotaciones de detección de robo.
    """

    # Colores para diferenciar a las personas
    ROBBERY_COLOR = (0, 0, 255)  # Rojo para personas robando
    NORMAL_COLOR = (0, 255, 0)    # Verde para personas normales

    # Definir estados de detección
    shoplifting_status = "Robando"
    not_shoplifting_status = "No robando"
    result = model.predict(frame)
    cc_data = np.array(result[0].boxes.data)

    if len(cc_data) != 0:
        xywh = np.array(result[0].boxes.xywh).astype("int32")
        xyxy = np.array(result[0].boxes.xyxy).astype("int32")
        
        for (x1, y1, x2, y2), (_, _, _, _), (_, _, _, _, conf, clas) in zip(xyxy, xywh, cc_data):
            if conf >= confidence_threshold:  # Solo considerar detecciones con alta confianza
                if clas == 1:  # Clase 1: Robo
                    color = ROBBERY_COLOR  # Rojo para personas robando
                    status = shoplifting_status
                else:  # Clase 0: No robo
                    color = NORMAL_COLOR  # Verde para personas normales
                    status = not_shoplifting_status

                # Dibujar el cuadro alrededor de la persona
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

                # Mostrar la confianza como texto
                text = f"{status} {conf * 100:.2f}%"
                cv2.putText(frame, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
    
    return frame

# %%
import os
import cv2
import numpy as np
import time
import json
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

video_path = "../data/par_nieve.mp4"
model_path = "../src/models/yolo11n.pt"
output_path = "../outputs/par_nieve.mp4"

# %%
# Load the YOLO model
model = YOLO(model_path)

# Open the video file and get properties
cap = initialize_video_capture(video_path)
w, h, fps = get_video_properties(cap)

# Initialize video writer
out = initialize_video_writer(output_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, w, h)

# Function to configure the line and directions
def configure_line(line_type, line_position, entry_direction, exit_direction):
    """
    Configure the line and directions for entry and exit.
    
    Args:
        line_type (str): "horizontal" or "vertical".
        line_position (int): Position of the line (Y for horizontal, X for vertical).
        entry_direction (str): Direction for entry ("up", "down", "left", "right").
        exit_direction (str): Direction for exit ("up", "down", "left", "right").
    
    Returns:
        tuple: Line start and end points, entry and exit conditions.
    """
    if line_type == "horizontal":
        line_start = (0, line_position)
        line_end = (w, line_position)
    else:  # Vertical
        line_start = (line_position, 0)
        line_end = (line_position, h)

    # Define conditions for entry and exit based on direction
    def crossed_line(current_pos, last_pos, line_pos, direction):
        if line_type == "horizontal":
            last_y, current_y = last_pos[1], current_pos[1]
            if direction == "down":
                return last_y < line_pos and current_y >= line_pos
            elif direction == "up":
                return last_y > line_pos and current_y <= line_pos
        else:  # Vertical
            last_x, current_x = last_pos[0], current_pos[0]
            if direction == "right":
                return last_x < line_pos and current_x >= line_pos
            elif direction == "left":
                return last_x > line_pos and current_x <= line_pos
        return False

    return line_start, line_end, crossed_line

# Configure the line and directions
line_type = "horizontal"  # Change to "vertical" if needed
line_position = h // 2 + 125  # Middle of the frame
entry_direction = "up"  # Enter when moving down
exit_direction = "down"  # Exit when moving up

line_start, line_end, crossed_line = configure_line(line_type, line_position, entry_direction, exit_direction)

# Initialize variables
prev_time = time.time()
last_positions = {}  # Track last positions of people
entry_times = {}  # Track entry times for each person
time_spent_list = []  # List to store time spent inside the area

while True:
    ret, frame = cap.read()
    if not ret:
        print("End of video.")
        break

    annotator = Annotator(frame, line_width=2)
    results = model.track(frame, persist=True)

    # Draw the line
    cv2.line(frame, line_start, line_end, (0, 255, 0), 2)  # Green line

    if results[0].boxes.id is not None:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        confs = results[0].boxes.conf.cpu().numpy()
        class_ids = results[0].boxes.cls.cpu().numpy()
        track_ids = results[0].boxes.id.int().cpu().tolist()

        for box, conf, class_id, track_id in zip(boxes, confs, class_ids, track_ids):
            # Check if the detected object is a person (class_id == 0)
            if int(class_id) == 0:  # 0 is typically the class_id for "person" in YOLO
                label = f"{model.names[int(class_id)]} {conf:.2f} ID: {track_id}"
                annotator.box_label(box, label, color=colors(track_id, True))

                # Calculate the centroid of the bounding box
                centroid_x = int((box[0] + box[2]) / 2)
                centroid_y = int((box[1] + box[3]) / 2)
                current_pos = (centroid_x, centroid_y)

                # Draw the centroid
                cv2.circle(frame, (centroid_x, centroid_y), 5, (0, 0, 255), -1)  # Red dot

                # Check if the person crossed the line
                if track_id in last_positions:
                    # Check for entry
                    if crossed_line(current_pos, last_positions[track_id], line_position, entry_direction):
                        if track_id not in entry_times:
                            entry_times[track_id] = time.time()  # Record entry time
                            print(f"Person {track_id} entered from {entry_direction} at {entry_times[track_id]}")

                    # Check for exit
                    if crossed_line(current_pos, last_positions[track_id], line_position, exit_direction):
                        if track_id in entry_times:
                            exit_time = time.time()
                            time_spent = exit_time - entry_times[track_id]
                            time_spent_list.append(time_spent)  # Add to the list
                            print(f"Person {track_id} exited to {exit_direction} after {time_spent:.2f} seconds")
                            del entry_times[track_id]  # Remove from entry times

                # Update last position
                last_positions[track_id] = current_pos

    current_time = time.time()
    fps = 1 / (current_time - prev_time)
    prev_time = current_time

    # Display statistics on the frame
    cv2.putText(frame, f"FPS: {fps:.2f}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    cv2.putText(frame, f"People in area: {len(entry_times)}", (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    out.write(frame)
    cv2.imshow("object-detection-tracking", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Calculate the average time spent inside the area
average_time_spent = sum(time_spent_list) / len(time_spent_list) if time_spent_list else 0

# Save the average time to a JSON file
with open("average_time_log.json", "w") as f:
    json.dump({"average_time_spent": average_time_spent}, f, indent=4)

print(f"Average time spent inside the area: {average_time_spent:.2f} seconds")

out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 persons, 83.3ms
# Speed: 4.4ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 149.4ms
# Speed: 2.0ms preprocess, 149.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 77.3ms
# Speed: 4.0ms preprocess, 77.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 77.6ms
# Speed: 4.6ms preprocess, 77.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 76.5ms
# Speed: 5.0ms preprocess, 76.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 77.9ms
# Speed: 4.7ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 73.4ms
# Speed: 3.3ms preprocess, 73.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.5ms
# Speed: 3.0ms preprocess, 69.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 72.5ms
# Speed: 3.2ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 72.5ms
# Speed: 2.9ms preprocess, 72.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 76.9ms
# Speed: 3.0ms preprocess, 76.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 78.7ms
# Speed: 2.0ms preprocess, 78.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 75.6ms
# Speed: 4.4ms preprocess, 75.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 350.2ms
# Speed: 19.4ms preprocess, 350.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 99.7ms
# Speed: 5.1ms preprocess, 99.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 85.1ms
# Speed: 3.7ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 76.4ms
# Speed: 3.0ms preprocess, 76.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 90.3ms
# Speed: 2.0ms preprocess, 90.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 72.4ms
# Speed: 3.5ms preprocess, 72.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 86.1ms
# Speed: 2.0ms preprocess, 86.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 107.9ms
# Speed: 5.3ms preprocess, 107.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 88.1ms
# Speed: 2.5ms preprocess, 88.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 89.3ms
# Speed: 3.0ms preprocess, 89.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 104.9ms
# Speed: 4.0ms preprocess, 104.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 90.7ms
# Speed: 2.5ms preprocess, 90.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 85.0ms
# Speed: 3.4ms preprocess, 85.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 75.2ms
# Speed: 2.0ms preprocess, 75.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 83.1ms
# Speed: 3.0ms preprocess, 83.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 84.1ms
# Speed: 3.1ms preprocess, 84.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 78.1ms
# Speed: 1.0ms preprocess, 78.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 80.2ms
# Speed: 3.0ms preprocess, 80.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.5ms
# Speed: 3.1ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 94.3ms
# Speed: 3.0ms preprocess, 94.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 113.6ms
# Speed: 3.3ms preprocess, 113.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 81.0ms
# Speed: 3.2ms preprocess, 81.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 131.4ms
# Speed: 4.2ms preprocess, 131.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 110.3ms
# Speed: 3.6ms preprocess, 110.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 95.8ms
# Speed: 4.0ms preprocess, 95.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 211.1ms
# Speed: 2.0ms preprocess, 211.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 216.8ms
# Speed: 5.1ms preprocess, 216.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 136.9ms
# Speed: 4.9ms preprocess, 136.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 127.5ms
# Speed: 6.0ms preprocess, 127.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 87.0ms
# Speed: 3.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 96.3ms
# Speed: 3.0ms preprocess, 96.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 93.8ms
# Speed: 3.0ms preprocess, 93.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 90.6ms
# Speed: 4.0ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 75.7ms
# Speed: 2.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 83.7ms
# Speed: 4.0ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 75.4ms
# Speed: 3.1ms preprocess, 75.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 1 entered from up at 1740598161.8714511
#
# 0: 384x640 2 persons, 120.0ms
# Speed: 2.0ms preprocess, 120.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 84.2ms
# Speed: 4.0ms preprocess, 84.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 76.2ms
# Speed: 2.0ms preprocess, 76.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 82.5ms
# Speed: 2.0ms preprocess, 82.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 145.7ms
# Speed: 3.0ms preprocess, 145.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 125.2ms
# Speed: 4.0ms preprocess, 125.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 105.6ms
# Speed: 3.0ms preprocess, 105.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 103.3ms
# Speed: 5.0ms preprocess, 103.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 73.5ms
# Speed: 3.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 80.5ms
# Speed: 4.0ms preprocess, 80.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 72.5ms
# Speed: 3.0ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 77.1ms
# Speed: 4.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 76.4ms
# Speed: 3.0ms preprocess, 76.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 152.7ms
# Speed: 29.0ms preprocess, 152.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 92.6ms
# Speed: 2.0ms preprocess, 92.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.9ms
# Speed: 2.0ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.5ms
# Speed: 2.5ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.9ms
# Speed: 2.0ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 62.5ms
# Speed: 2.1ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.6ms
# Speed: 3.0ms preprocess, 68.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.0ms
# Speed: 3.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.9ms
# Speed: 3.0ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 62.6ms
# Speed: 2.2ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.3ms
# Speed: 2.0ms preprocess, 68.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.3ms
# Speed: 2.0ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.9ms
# Speed: 2.1ms preprocess, 68.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 62.1ms
# Speed: 2.5ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 62.5ms
# Speed: 3.1ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.8ms
# Speed: 3.0ms preprocess, 65.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.2ms
# Speed: 3.0ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.1ms
# Speed: 2.2ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 114.4ms
# Speed: 2.0ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 62.7ms
# Speed: 3.0ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.9ms
# Speed: 2.0ms preprocess, 65.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.2ms
# Speed: 2.0ms preprocess, 66.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.8ms
# Speed: 3.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.9ms
# Speed: 3.0ms preprocess, 68.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.0ms
# Speed: 3.2ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.2ms
# Speed: 3.0ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.7ms
# Speed: 2.1ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.0ms
# Speed: 3.0ms preprocess, 67.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.4ms
# Speed: 3.0ms preprocess, 65.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.7ms
# Speed: 3.0ms preprocess, 65.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.1ms
# Speed: 3.0ms preprocess, 67.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.1ms
# Speed: 3.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.6ms
# Speed: 2.0ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 72.8ms
# Speed: 4.0ms preprocess, 72.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.4ms
# Speed: 3.0ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.8ms
# Speed: 3.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.5ms
# Speed: 3.7ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.5ms
# Speed: 3.0ms preprocess, 64.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.1ms
# Speed: 2.2ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.9ms
# Speed: 2.0ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.1ms
# Speed: 3.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.3ms
# Speed: 2.0ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.2ms
# Speed: 3.0ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.9ms
# Speed: 2.0ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.2ms
# Speed: 2.1ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.6ms
# Speed: 3.1ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.6ms
# Speed: 2.0ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.8ms
# Speed: 2.1ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.9ms
# Speed: 3.1ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.4ms
# Speed: 3.0ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.6ms
# Speed: 3.0ms preprocess, 64.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.6ms
# Speed: 4.2ms preprocess, 63.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.2ms
# Speed: 2.6ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.8ms
# Speed: 3.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.6ms
# Speed: 3.0ms preprocess, 63.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 75.0ms
# Speed: 3.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 75.6ms
# Speed: 3.5ms preprocess, 75.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.7ms
# Speed: 2.1ms preprocess, 67.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 62.4ms
# Speed: 3.0ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.5ms
# Speed: 3.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.8ms
# Speed: 4.1ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.9ms
# Speed: 2.1ms preprocess, 67.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.1ms
# Speed: 3.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 2 entered from up at 1740598176.4591405
#
# 0: 384x640 2 persons, 64.9ms
# Speed: 3.0ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.7ms
# Speed: 3.0ms preprocess, 68.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.4ms
# Speed: 2.0ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.0ms
# Speed: 6.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.9ms
# Speed: 3.0ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.7ms
# Speed: 3.4ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.6ms
# Speed: 2.1ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.4ms
# Speed: 3.0ms preprocess, 63.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.7ms
# Speed: 3.0ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.0ms
# Speed: 2.2ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.9ms
# Speed: 3.2ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.4ms
# Speed: 3.0ms preprocess, 65.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 99.3ms
# Speed: 2.0ms preprocess, 99.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 90.7ms
# Speed: 4.0ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 2 exited to down after 2.48 seconds
#
# 0: 384x640 2 persons, 107.6ms
# Speed: 8.5ms preprocess, 107.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.8ms
# Speed: 2.0ms preprocess, 70.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.6ms
# Speed: 2.2ms preprocess, 67.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.9ms
# Speed: 2.5ms preprocess, 70.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.7ms
# Speed: 2.1ms preprocess, 65.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.8ms
# Speed: 3.2ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.8ms
# Speed: 2.2ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.4ms
# Speed: 2.1ms preprocess, 65.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 2 entered from up at 1740598180.4512315
#
# 0: 384x640 2 persons, 66.4ms
# Speed: 2.5ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.9ms
# Speed: 3.0ms preprocess, 63.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.9ms
# Speed: 3.0ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 62.3ms
# Speed: 3.0ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 2 exited to down after 0.56 seconds
#
# 0: 384x640 2 persons, 64.8ms
# Speed: 3.1ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.5ms
# Speed: 4.6ms preprocess, 67.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 108.5ms
# Speed: 3.0ms preprocess, 108.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 91.5ms
# Speed: 4.0ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.3ms
# Speed: 3.0ms preprocess, 68.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.2ms
# Speed: 3.0ms preprocess, 67.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 83.5ms
# Speed: 4.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.9ms
# Speed: 2.0ms preprocess, 69.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.2ms
# Speed: 3.2ms preprocess, 70.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 83.4ms
# Speed: 3.1ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 2 entered from up at 1740598182.7938976
#
# 0: 384x640 2 persons, 72.7ms
# Speed: 3.0ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 493.3ms
# Speed: 201.4ms preprocess, 493.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 115.5ms
# Speed: 3.0ms preprocess, 115.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 647.9ms
# Speed: 3.0ms preprocess, 647.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 224.4ms
# Speed: 6.0ms preprocess, 224.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 212.2ms
# Speed: 9.0ms preprocess, 212.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 2 exited to down after 2.59 seconds
#
# 0: 384x640 2 persons, 166.8ms
# Speed: 4.0ms preprocess, 166.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 228.8ms
# Speed: 4.0ms preprocess, 228.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 299.3ms
# Speed: 17.1ms preprocess, 299.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 247.8ms
# Speed: 7.1ms preprocess, 247.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 331.7ms
# Speed: 5.6ms preprocess, 331.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 332.5ms
# Speed: 17.5ms preprocess, 332.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.8ms
# Speed: 4.0ms preprocess, 160.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 137.8ms
# Speed: 6.5ms preprocess, 137.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 2 entered from up at 1740598188.4233322
#
# 0: 384x640 2 persons, 177.7ms
# Speed: 3.5ms preprocess, 177.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 145.3ms
# Speed: 4.5ms preprocess, 145.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 276.7ms
# Speed: 3.0ms preprocess, 276.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.7ms
# Speed: 3.1ms preprocess, 165.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 904.4ms
# Speed: 21.2ms preprocess, 904.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 289.8ms
# Speed: 18.2ms preprocess, 289.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.3ms
# Speed: 5.5ms preprocess, 166.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 103.7ms
# Speed: 4.0ms preprocess, 103.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 106.8ms
# Speed: 3.0ms preprocess, 106.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.7ms
# Speed: 12.3ms preprocess, 157.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 89.0ms
# Speed: 4.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 110.5ms
# Speed: 3.0ms preprocess, 110.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 126.5ms
# Speed: 4.5ms preprocess, 126.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 100.5ms
# Speed: 4.0ms preprocess, 100.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 135.5ms
# Speed: 2.0ms preprocess, 135.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 113.0ms
# Speed: 8.5ms preprocess, 113.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 128.0ms
# Speed: 4.0ms preprocess, 128.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 84.3ms
# Speed: 4.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 119.3ms
# Speed: 3.2ms preprocess, 119.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 85.3ms
# Speed: 3.2ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 76.7ms
# Speed: 3.0ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 76.9ms
# Speed: 3.0ms preprocess, 76.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 95.7ms
# Speed: 3.0ms preprocess, 95.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 75.2ms
# Speed: 3.0ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 74.1ms
# Speed: 3.0ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 93.9ms
# Speed: 5.0ms preprocess, 93.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.9ms
# Speed: 3.0ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 87.8ms
# Speed: 2.0ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 89.5ms
# Speed: 4.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 98.5ms
# Speed: 2.1ms preprocess, 98.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 110.3ms
# Speed: 3.0ms preprocess, 110.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 98.5ms
# Speed: 3.0ms preprocess, 98.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 82.7ms
# Speed: 3.0ms preprocess, 82.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 86.3ms
# Speed: 3.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 114.8ms
# Speed: 3.0ms preprocess, 114.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 113.5ms
# Speed: 4.0ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 2 exited to down after 9.26 seconds
#
# 0: 384x640 2 persons, 75.1ms
# Speed: 3.0ms preprocess, 75.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.1ms
# Speed: 3.2ms preprocess, 67.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.4ms
# Speed: 3.2ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 73.8ms
# Speed: 3.0ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 2 entered from up at 1740598198.286546
#
# 0: 384x640 2 persons, 100.9ms
# Speed: 2.0ms preprocess, 100.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 319.0ms
# Speed: 10.0ms preprocess, 319.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 599.3ms
# Speed: 20.0ms preprocess, 599.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 232.0ms
# Speed: 9.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 115.4ms
# Speed: 3.0ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 96.0ms
# Speed: 3.0ms preprocess, 96.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 298.1ms
# Speed: 5.6ms preprocess, 298.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 123.9ms
# Speed: 3.0ms preprocess, 123.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 2 exited to down after 2.88 seconds
#
# 0: 384x640 2 persons, 115.7ms
# Speed: 3.5ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 106.8ms
# Speed: 4.5ms preprocess, 106.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 105.0ms
# Speed: 4.2ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 101.5ms
# Speed: 3.0ms preprocess, 101.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 124.3ms
# Speed: 3.0ms preprocess, 124.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 203.7ms
# Speed: 11.0ms preprocess, 203.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Person 2 entered from up at 1740598202.6015475
#
# 0: 384x640 2 persons, 265.6ms
# Speed: 6.6ms preprocess, 265.6ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 205.5ms
# Speed: 4.5ms preprocess, 205.5ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 332.6ms
# Speed: 37.4ms preprocess, 332.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 119.9ms
# Speed: 3.0ms preprocess, 119.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 120.2ms
# Speed: 3.5ms preprocess, 120.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 275.7ms
# Speed: 4.5ms preprocess, 275.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 262.6ms
# Speed: 6.0ms preprocess, 262.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 275.8ms
# Speed: 3.0ms preprocess, 275.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 196.2ms
# Speed: 5.0ms preprocess, 196.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 390.0ms
# Speed: 5.6ms preprocess, 390.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 313.1ms
# Speed: 44.2ms preprocess, 313.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 203.3ms
# Speed: 5.0ms preprocess, 203.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 139.8ms
# Speed: 4.0ms preprocess, 139.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.1ms
# Speed: 2.0ms preprocess, 69.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.8ms
# Speed: 2.2ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 78.3ms
# Speed: 3.0ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 73.3ms
# Speed: 2.0ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.6ms
# Speed: 2.2ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 83.2ms
# Speed: 3.0ms preprocess, 83.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.9ms
# Speed: 3.0ms preprocess, 68.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 64.8ms
# Speed: 3.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 112.8ms
# Speed: 2.0ms preprocess, 112.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 74.1ms
# Speed: 3.2ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 102.2ms
# Speed: 3.0ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.3ms
# Speed: 4.0ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 81.1ms
# Speed: 3.0ms preprocess, 81.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 103.6ms
# Speed: 12.2ms preprocess, 103.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.7ms
# Speed: 3.2ms preprocess, 66.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 132.0ms
# Speed: 3.0ms preprocess, 132.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 87.0ms
# Speed: 2.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 85.1ms
# Speed: 3.0ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 98.5ms
# Speed: 3.0ms preprocess, 98.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 82.1ms
# Speed: 3.0ms preprocess, 82.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 82.9ms
# Speed: 3.0ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.7ms
# Speed: 3.0ms preprocess, 70.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.8ms
# Speed: 3.1ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 92.9ms
# Speed: 4.0ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.8ms
# Speed: 4.0ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.9ms
# Speed: 3.2ms preprocess, 65.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 72.1ms
# Speed: 2.0ms preprocess, 72.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 78.3ms
# Speed: 2.2ms preprocess, 78.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 113.0ms
# Speed: 4.0ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 84.2ms
# Speed: 5.0ms preprocess, 84.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 89.5ms
# Speed: 4.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 117.6ms
# Speed: 4.0ms preprocess, 117.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 99.2ms
# Speed: 3.1ms preprocess, 99.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 89.8ms
# Speed: 2.0ms preprocess, 89.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 96.4ms
# Speed: 2.9ms preprocess, 96.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 101.1ms
# Speed: 3.0ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 127.6ms
# Speed: 3.5ms preprocess, 127.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 115.7ms
# Speed: 4.5ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 97.5ms
# Speed: 2.5ms preprocess, 97.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 67.9ms
# Speed: 2.2ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 72.5ms
# Speed: 3.0ms preprocess, 72.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.8ms
# Speed: 3.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 83.6ms
# Speed: 3.0ms preprocess, 83.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 114.2ms
# Speed: 33.7ms preprocess, 114.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 95.0ms
# Speed: 3.0ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 85.2ms
# Speed: 4.0ms preprocess, 85.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 70.4ms
# Speed: 2.0ms preprocess, 70.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 97.4ms
# Speed: 6.1ms preprocess, 97.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 84.8ms
# Speed: 2.0ms preprocess, 84.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.5ms
# Speed: 3.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.4ms
# Speed: 3.0ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.5ms
# Speed: 3.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 84.7ms
# Speed: 3.0ms preprocess, 84.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 83.5ms
# Speed: 4.0ms preprocess, 83.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 66.9ms
# Speed: 3.1ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 75.3ms
# Speed: 3.2ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.9ms
# Speed: 3.0ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 84.8ms
# Speed: 3.2ms preprocess, 84.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 86.4ms
# Speed: 2.0ms preprocess, 86.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 81.1ms
# Speed: 3.2ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.9ms
# Speed: 3.0ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.9ms
# Speed: 2.0ms preprocess, 69.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 135.2ms
# Speed: 3.0ms preprocess, 135.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 92.5ms
# Speed: 3.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 71.4ms
# Speed: 3.0ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 297.8ms
# Speed: 6.4ms preprocess, 297.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 368.5ms
# Speed: 7.0ms preprocess, 368.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 122.8ms
# Speed: 12.3ms preprocess, 122.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 138.5ms
# Speed: 7.5ms preprocess, 138.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 103.8ms
# Speed: 3.0ms preprocess, 103.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 108.7ms
# Speed: 3.8ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 127.9ms
# Speed: 5.5ms preprocess, 127.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 106.6ms
# Speed: 2.0ms preprocess, 106.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 123.2ms
# Speed: 2.5ms preprocess, 123.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 200.5ms
# Speed: 3.5ms preprocess, 200.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 238.6ms
# Speed: 29.1ms preprocess, 238.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 638.0ms
# Speed: 5.3ms preprocess, 638.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 103.8ms
# Speed: 3.5ms preprocess, 103.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 111.4ms
# Speed: 4.5ms preprocess, 111.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 145.1ms
# Speed: 3.0ms preprocess, 145.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 236.8ms
# Speed: 3.0ms preprocess, 236.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 122.9ms
# Speed: 2.5ms preprocess, 122.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 136.5ms
# Speed: 5.0ms preprocess, 136.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 170.0ms
# Speed: 51.1ms preprocess, 170.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 146.3ms
# Speed: 9.0ms preprocess, 146.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 144.7ms
# Speed: 3.0ms preprocess, 144.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 128.5ms
# Speed: 4.2ms preprocess, 128.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 273.2ms
# Speed: 5.0ms preprocess, 273.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.8ms
# ...
# Speed: 3.0ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.7ms
# Speed: 3.0ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 79.6ms
# Speed: 3.0ms preprocess, 79.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 73.7ms
# Speed: 4.0ms preprocess, 73.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.8ms
# Speed: 4.1ms preprocess, 77.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 77.4ms
# Speed: 2.0ms preprocess, 77.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.5ms
# Speed: 4.2ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 fire hydrant, 102.4ms
# Speed: 3.0ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 79.5ms
# Speed: 4.1ms preprocess, 79.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.6ms
# Speed: 3.2ms preprocess, 113.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 90.0ms
# Speed: 4.0ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire hydrant, 100.2ms
# Speed: 3.5ms preprocess, 100.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.8ms
# Speed: 4.0ms preprocess, 118.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 110.5ms
# Speed: 7.5ms preprocess, 110.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 90.8ms
# Speed: 4.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 118.6ms
# Speed: 28.8ms preprocess, 118.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 112.0ms
# Speed: 6.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 90.7ms
# Speed: 4.2ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 81.6ms
# Speed: 5.0ms preprocess, 81.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 78.7ms
# Speed: 3.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.9ms
# Speed: 3.0ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.2ms
# Speed: 3.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 74.6ms
# Speed: 2.0ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 98.4ms
# Speed: 4.0ms preprocess, 98.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 79.7ms
# Speed: 4.0ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 67.1ms
# Speed: 4.0ms preprocess, 67.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.7ms
# Speed: 3.0ms preprocess, 65.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 70.9ms
# Speed: 3.0ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 87.4ms
# Speed: 13.5ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.8ms
# Speed: 3.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.9ms
# Speed: 3.0ms preprocess, 166.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 99.7ms
# Speed: 3.5ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 109.5ms
# Speed: 6.0ms preprocess, 109.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 80.5ms
# Speed: 3.0ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 111.5ms
# Speed: 5.0ms preprocess, 111.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 113.5ms
# Speed: 7.0ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 100.5ms
# Speed: 4.0ms preprocess, 100.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 125.1ms
# Speed: 3.0ms preprocess, 125.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 152.5ms
# Speed: 5.0ms preprocess, 152.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 136.1ms
# Speed: 3.0ms preprocess, 136.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 139.1ms
# Speed: 10.0ms preprocess, 139.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 142.7ms
# Speed: 6.0ms preprocess, 142.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.4ms
# Speed: 3.5ms preprocess, 167.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 fire hydrant, 133.2ms
# Speed: 4.0ms preprocess, 133.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 122.8ms
# Speed: 3.5ms preprocess, 122.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 128.4ms
# Speed: 4.0ms preprocess, 128.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 139.9ms
# Speed: 3.0ms preprocess, 139.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.5ms
# Speed: 5.0ms preprocess, 159.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 182.0ms
# Speed: 5.0ms preprocess, 182.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 165.8ms
# Speed: 4.0ms preprocess, 165.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 236.9ms
# Speed: 5.7ms preprocess, 236.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 165.5ms
# Speed: 6.0ms preprocess, 165.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.5ms
# Speed: 7.0ms preprocess, 167.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.1ms
# Speed: 9.0ms preprocess, 175.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 216.4ms
# Speed: 10.4ms preprocess, 216.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.0ms
# Speed: 5.0ms preprocess, 168.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 147.6ms
# Speed: 5.0ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 140.9ms
# Speed: 5.0ms preprocess, 140.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 243.8ms
# Speed: 7.0ms preprocess, 243.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.5ms
# Speed: 10.0ms preprocess, 159.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire hydrant, 150.1ms
# Speed: 3.5ms preprocess, 150.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire hydrant, 138.5ms
# Speed: 5.0ms preprocess, 138.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire hydrant, 140.5ms
# Speed: 5.0ms preprocess, 140.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire hydrant, 145.2ms
# Speed: 4.0ms preprocess, 145.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire hydrant, 178.5ms
# Speed: 3.0ms preprocess, 178.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 131.6ms
# Speed: 7.0ms preprocess, 131.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire hydrant, 134.1ms
# Speed: 6.0ms preprocess, 134.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.5ms
# Speed: 7.0ms preprocess, 124.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 132.6ms
# Speed: 7.0ms preprocess, 132.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 129.5ms
# Speed: 5.0ms preprocess, 129.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 140.5ms
# Speed: 4.5ms preprocess, 140.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 133.3ms
# Speed: 5.0ms preprocess, 133.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 137.1ms
# Speed: 4.0ms preprocess, 137.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 140.6ms
# Speed: 4.0ms preprocess, 140.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 143.5ms
# Speed: 4.0ms preprocess, 143.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 145.8ms
# Speed: 4.0ms preprocess, 145.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 139.1ms
# Speed: 4.0ms preprocess, 139.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.5ms
# Speed: 4.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.5ms
# Speed: 5.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.6ms
# Speed: 4.0ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.0ms
# Speed: 3.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.0ms
# Speed: 4.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.5ms
# Speed: 3.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.5ms
# Speed: 4.0ms preprocess, 76.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.5ms
# Speed: 3.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.5ms
# Speed: 4.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.5ms
# Speed: 3.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 130.1ms
# Speed: 4.0ms preprocess, 130.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.5ms
# Speed: 2.0ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.5ms
# Speed: 5.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.5ms
# Speed: 3.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.5ms
# Speed: 3.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.5ms
# Speed: 4.0ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.5ms
# Speed: 3.5ms preprocess, 112.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.5ms
# Speed: 2.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.5ms
# Speed: 4.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.5ms
# Speed: 5.0ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.5ms
# Speed: 4.0ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.0ms
# Speed: 3.5ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.5ms
# Speed: 3.0ms preprocess, 84.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.5ms
# Speed: 4.0ms preprocess, 85.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.5ms
# Speed: 3.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.5ms
# Speed: 4.0ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.6ms
# Speed: 5.0ms preprocess, 72.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.5ms
# Speed: 4.1ms preprocess, 74.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.5ms
# Speed: 4.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 282.6ms
# Speed: 3.0ms preprocess, 282.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 165.1ms
# Speed: 7.0ms preprocess, 165.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 209.0ms
# Speed: 3.0ms preprocess, 209.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.6ms
# Speed: 7.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 200.5ms
# Speed: 10.3ms preprocess, 200.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 164.7ms
# Speed: 4.0ms preprocess, 164.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 208.0ms
# Speed: 6.0ms preprocess, 208.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 118.0ms
# Speed: 5.0ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.2ms
# Speed: 8.9ms preprocess, 244.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 186.2ms
# Speed: 6.6ms preprocess, 186.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# End of video.
# Average time spent inside the area: 3.56 seconds
